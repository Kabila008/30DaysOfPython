# %% [markdown]
# evel_one

# %%
import re 
import string 
from collection import counter 
from pprint import pprint
  
 paragraphÂ =Â "IÂ loveÂ teaching.Â IfÂ youÂ doÂ notÂ loveÂ teachingÂ whatÂ elseÂ canÂ youÂ love.Â IÂ loveÂ PythonÂ ifÂ youÂ doÂ notÂ loveÂ "Â \ 
 Â Â Â Â Â Â Â Â Â Â Â Â "somethingÂ whichÂ canÂ giveÂ youÂ allÂ theÂ capabilitiesÂ toÂ developÂ anÂ applicationÂ whatÂ elseÂ canÂ youÂ love.Â " 
  
  
 defÂ most_common_words(text): 
 Â Â Â Â split_itÂ =Â text.split() 
 Â Â Â Â CnterÂ =Â Counter(split_it).most_common() 
 Â Â Â Â #Â Cnter.sort(reverse=True) 
 Â Â Â Â returnÂ Cnter 
  
  
 pprint(most_common_words(paragraph)) 
 #Level_two
 num_listÂ =Â list(map(int,Â re.findall(r"[-+]?[.]?[\d]+",Â para))) 
 num_list.sort() 
 pprint(num_list) 
 distÂ =Â num_list[-1]Â -Â num_list[0] 
 pprint(dist) 
  
  
 defÂ is_valid_variable(potential_variable): 
 Â Â Â Â ifÂ re.search(r"^[a-zA-Z_]\w*$",Â potential_variable): 
 Â Â Â Â Â Â Â Â returnÂ True 
 Â Â Â Â else: 
 Â Â Â Â Â Â Â Â returnÂ False 
  
  #Level_three 
 pprint(is_valid_variable("first_name")) 
 pprint(is_valid_variable("first-name")) 
  
defÂ clean_text(text): 
 Â Â Â Â textÂ =Â text.lower() 
 Â Â Â Â textÂ =Â re.sub("\[.*?]",Â "",Â text) 
 Â Â Â Â textÂ =Â re.sub("https?://\S+|www\.\S+",Â "",Â text) 
 Â Â Â Â textÂ =Â re.sub("<.*?>+",Â "",Â text) 
 Â Â Â Â textÂ =Â re.sub("[%s]"Â %Â re.escape(string.punctuation),Â "",Â text) 
 Â Â Â Â textÂ =Â re.sub("\n",Â "",Â text) 
 Â Â Â Â textÂ =Â re.sub("\w*\d\w*",Â "",Â text) 
 Â Â Â Â returnÂ text 
  
  
 pprint(clean_text(sentence)) 
 pprint(most_common_words(clean_text(sentence))[:3])
