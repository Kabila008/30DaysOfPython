# %% [markdown]
# Exercise: Level 1

# %% [markdown]
# Day 2: 30 Days of python programming

# %%
first_name = 'Kabila'
last_name = 'Musa'
full_name = first_name + ' '+ last_name
country_name = 'Nigeria'
city = 'Kano'
age = 29
year = 2023
is_married = True
is_true = True
is_light_on = is_true
name, school, fruit, color, car = 'Abdullahi', 'Al-Azhar', 'Orange', 'Blue', 'Benz'

# %% [markdown]
# Exercise: Level 2

# %% [markdown]
# 1. Check the data type of all your variables using type() built-in function

# %%
print(type(first_name))
print(type(last_name))
print(type(full_name))
print(type(country_name))
print(type(city))
print(type(age))
print(type(year))
print(type(is_married))
print(type(is_true))
print(type(is_light_on))

# %% [markdown]
# 2. Using the len() built-in function, find the length of your first name

# %%
print(len(first_name))

# %% [markdown]
# 3. Compare the length of your first name and your last name

# %%
print(len(first_name) == len(last_name))

# %% [markdown]
# 4. Declare 5 as num_one and 4 as num_two

# %%
num_one, num_two = 5, 4

# %%
num_tot = num_one + num_two
num_diff = num_one - num_two
num_mul = num_one * num_two
num_div = num_one / num_two
num_mod = num_one % num_two
num_exp = num_one ** num_two
num_flr = num_one // num_two

# %%
print(num_tot)

# %% [markdown]
# <br>
#     5. The radius of a circle is 30 meters.<br>
#     Calculate the area of a circle and assign the value to a variable name of area_of_circle<br>
#     Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle<br>
#     Take radius as user input and calculate the area.<br>

# %%
radius = 30
pi = 3.14
#radius = int(input('Enter radius'))

# %% [markdown]
# i.

# %%
Area_of_circle = pi * (radius)**2

# %%
print(Area_of_circle)

# %% [markdown]
# i

# %%
circum_of_circle = 2 * pi * 30

# %%
print(circum_of_circle)

# %% [markdown]
# ii

# %%
pi = 3.14
radius = float(input('Enter radius'))

# %%
Area_of_circle = pi * (radius)**2

# %%
circum_of_circle = 2 * pi * radius

# %% [markdown]
# rint(Area_of_circle)<br>
# rint(circum_of_circle)

# %% [markdown]
# <br>
#     6. Use the built-in input function to get <br>
#     first name, last name, country and age <br>
#     from a user and store the value to their corresponding variable names<br>

# %%
First_name = str(input('Enter Your First Name'))
Last_name = str(input('Enter Your Last Name'))
Country = str(input('Enter Your Country Name'))
Age = int(input('Enter Your Age'))

# %% [markdown]
# <br>
# Run help('keywords') in Python shell <br>
# or in your file to check for the Python reserved words or keywords<br>

# %%
print(help('keywords'))
