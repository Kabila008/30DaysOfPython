# %%
 #Repeated all the examples as follows. 
 importÂ numpyÂ asÂ np 
 importÂ matplotlib.pyplotÂ asÂ plt 
 importÂ seabornÂ asÂ sns 
 fromÂ scipyÂ importÂ stats 
  
 print('numpy:',Â np.__version__) 
 print(dir(np)) 
  
 python_listÂ =Â [1,Â 2,Â 3,Â 4,Â 5] 
  
 print('Type:',Â type(python_list)) 
 print(python_list) 
  
 two_dimensional_listÂ =Â [[0,Â 1,Â 2],Â [3,Â 4,Â 5],Â [6,Â 7,Â 8]] 
  
 print(two_dimensional_list) 
  
 numpy_array_from_listÂ =Â np.array(python_list) 
 print(type(numpy_array_from_list)) 
 print(numpy_array_from_list) 
 python_listÂ =Â [1,Â 2,Â 3,Â 4,Â 5] 
  
 numy_array_from_list2Â =Â np.array(python_list,Â dtype=float) 
 print(numy_array_from_list2) 
 numpy_bool_arrayÂ =Â np.array([0,Â 1,Â -1,Â 0,Â 0],Â dtype=bool) 
 print(numpy_bool_array) 
  
 two_dimensional_listÂ =Â [[0,Â 1,Â 2],Â [3,Â 4,Â 5],Â [6,Â 7,Â 8]] 
 numpy_two_dimensional_listÂ =Â np.array(two_dimensional_list) 
 print(type(numpy_two_dimensional_list)) 
 print(numpy_two_dimensional_list) 
  
 np_to_listÂ =Â numpy_array_from_list.tolist() 
 print(type(np_to_list)) 
 print('oneÂ dimensionalÂ array:',Â np_to_list) 
 print('twoÂ dimensionalÂ array:Â ',Â numpy_two_dimensional_list.tolist()) 
  
 python_tupleÂ =Â (1,Â 2,Â 3,Â 4,Â 5) 
 print(type(python_tuple)) 
 print('python_tuple:Â ',Â python_tuple) 
  
 numpy_array_from_tupleÂ =Â np.array(python_tuple) 
 print(type(numpy_array_from_tuple)) 
 print('numpy_array_from_tuple:Â ',Â numpy_array_from_tuple) 
  
 numsÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print(nums) 
 print('shapeÂ ofÂ nums:Â ',Â nums.shape) 
 print(numpy_two_dimensional_list) 
 print('shapeÂ ofÂ numpy_two_dimensional_list:Â ',Â numpy_two_dimensional_list.shape) 
 three_by_four_arrayÂ =Â np.array([[0,Â 1,Â 2,Â 3], 
 Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â [4,Â 5,Â 6,Â 7], 
 Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â [8,Â 9,Â 10,Â 11]]) 
 print(three_by_four_array.shape) 
  
 int_listsÂ =Â [-3,Â -2,Â -1,Â 0,Â 1,Â 2,Â 3] 
 int_arrayÂ =Â np.array(int_lists) 
 float_arrayÂ =Â np.array(int_lists,Â dtype=float) 
  
 print(int_array) 
 print(int_array.dtype) 
 print(float_array) 
 print(float_array.dtype) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 two_dimensional_listÂ =Â np.array([[0,Â 1,Â 2], 
 Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â [3,Â 4,Â 5], 
 Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â Â [6,Â 7,Â 8]]) 
  
 print('TheÂ size:',Â numpy_array_from_list.size) 
 print('TheÂ size:',Â two_dimensional_list.size) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print('originalÂ array:Â ',Â numpy_array_from_list) 
 ten_plus_originalÂ =Â numpy_array_from_listÂ +Â 10 
 print(ten_plus_original) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print('originalÂ array:Â ',Â numpy_array_from_list) 
 ten_minus_originalÂ =Â numpy_array_from_listÂ -Â 10 
 print(ten_minus_original) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print('originalÂ array:Â ',Â numpy_array_from_list) 
 ten_times_originalÂ =Â numpy_array_from_listÂ *Â 10 
 print(ten_times_original) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print('originalÂ array:Â ',Â numpy_array_from_list) 
 ten_times_originalÂ =Â numpy_array_from_listÂ /Â 10 
 print(ten_times_original) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print('originalÂ array:Â ',Â numpy_array_from_list) 
 ten_times_originalÂ =Â numpy_array_from_listÂ %Â 3 
 print(ten_times_original) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print('originalÂ array:Â ',Â numpy_array_from_list) 
 ten_times_originalÂ =Â numpy_array_from_listÂ //Â 10 
 print(ten_times_original) 
  
 numpy_array_from_listÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 print('originalÂ array:Â ',Â numpy_array_from_list) 
 ten_times_originalÂ =Â numpy_array_from_listÂ **Â 2 
 print(ten_times_original) 
  
 numpy_int_arrÂ =Â np.array([1,Â 2,Â 3,Â 4]) 
 numpy_float_arrÂ =Â np.array([1.1,Â 2.0,Â 3.2]) 
 numpy_bool_arrÂ =Â np.array([-3,Â -2,Â 0,Â 1,Â 2,Â 3],Â dtype='bool') 
  
 print(numpy_int_arr.dtype) 
 print(numpy_float_arr.dtype) 
 print(numpy_bool_arr.dtype) 
  
 two_dimension_arrayÂ =Â np.array([(1,Â 2,Â 3),Â (4,Â 5,Â 6),Â (7,Â 8,Â 9)]) 
 print(type(two_dimension_array)) 
 print(two_dimension_array) 
 print('Shape:Â ',Â two_dimension_array.shape) 
 print('Size:',Â two_dimension_array.size) 
 print('DataÂ type:',Â two_dimension_array.dtype) 
  
 two_dimension_arrayÂ =Â np.array([[1,Â 2,Â 3],Â [4,Â 5,Â 6],Â [7,Â 8,Â 9]]) 
 first_rowÂ =Â two_dimension_array[0] 
 second_rowÂ =Â two_dimension_array[1] 
 third_rowÂ =Â two_dimension_array[2] 
 print('FirstÂ row:',Â first_row) 
 print('SecondÂ row:',Â second_row) 
 print('ThirdÂ row:Â ',Â third_row) 
  
 first_columnÂ =Â two_dimension_array[:,Â 0] 
 second_columnÂ =Â two_dimension_array[:,Â 1] 
 third_columnÂ =Â two_dimension_array[:,Â 2] 
 print('FirstÂ column:',Â first_column) 
 print('SecondÂ column:',Â second_column) 
 print('ThirdÂ column:Â ',Â third_column) 
 print(two_dimension_array) 
  
 two_dimension_arrayÂ =Â np.array([[1,Â 2,Â 3],Â [4,Â 5,Â 6],Â [7,Â 8,Â 9]]) 
 first_two_rows_and_columnsÂ =Â two_dimension_array[0:2,Â 0:2] 
 print(first_two_rows_and_columns) 
  
 two_dimension_arrayÂ =Â np.array([[1,Â 2,Â 3],Â [4,Â 5,Â 6],Â [7,Â 8,Â 9]]) 
 print(two_dimension_array[::-1,Â ::-1]) 
  
 print(two_dimension_array) 
 two_dimension_array[1,Â 1]Â =Â 55 
 two_dimension_array[1,Â 2]Â =Â 44 
 print(two_dimension_array) 
  
 numpy_onesÂ =Â np.ones((3,Â 3),Â dtype=int,Â order='C') 
 print(numpy_ones) 
  
 first_shapeÂ =Â np.array([(1,Â 2,Â 3),Â (4,Â 5,Â 6)]) 
 print(first_shape) 
 reshapedÂ =Â first_shape.reshape(3,Â 2) 
 print(reshaped) 
  
 np_list_oneÂ =Â np.array([1,Â 2,Â 3]) 
 np_list_twoÂ =Â np.array([4,Â 5,Â 6]) 
  
 print(np_list_oneÂ +Â np_list_two) 
  
 print('HorizontalÂ Append:',Â np.hstack((np_list_one,Â np_list_two))) 
  
 print('VerticalÂ Append:',Â np.vstack((np_list_one,Â np_list_two))) 
  
 normal_arrayÂ =Â np.random.normal(79,Â 15,Â 80) 
 sns.set() 
 plt.hist(normal_array,Â color="grey",Â bins=50) 
 plt.show() 
 np_normal_disÂ =Â np.random.normal(5,Â 0.5,Â 100) 
 #Â noinspectionÂ PyArgumentList 
 print('min:Â ',Â two_dimension_array.min()) 
 #Â noinspectionÂ PyArgumentList 
 print('max:Â ',Â two_dimension_array.max()) 
 print('mean:Â ',Â two_dimension_array.mean()) 
 print('sd:Â ',Â two_dimension_array.std()) 
  
 print(two_dimension_array) 
 print('ColumnÂ withÂ minimum:Â ',Â np.amin(two_dimension_array,Â axis=0)) 
 print('ColumnÂ withÂ maximum:Â ',Â np.amax(two_dimension_array,Â axis=0)) 
 print('===Â RowÂ ==') 
 print('RowÂ withÂ minimum:Â ',Â np.amin(two_dimension_array,Â axis=1)) 
 print('RowÂ withÂ maximum:Â ',Â np.amax(two_dimension_array,Â axis=1)) 
  
 aÂ =Â [1,Â 2,Â 3] 
  
 print('Tile:Â Â Â ',Â np.tile(a,Â 2)) 
  
 print('Repeat:Â ',Â np.repeat(a,Â 2)) 
  
 one_random_numÂ =Â np.random.random() 
 one_random_inÂ =Â np.random 
 print(one_random_num) 
  
 rÂ =Â np.random.random(size=[2,Â 3]) 
 print(r) 
  
 print(np.random.choice(['a',Â 'e',Â 'i',Â 'o',Â 'u'],Â size=10)) 
  
 #Â noinspectionÂ PyRedeclaration 
 np_normal_disÂ =Â np.random.normal(5,Â 0.5,Â 1000) 
  
 print('min:Â ',Â np.min(np_normal_dis)) 
 print('max:Â ',Â np.max(np_normal_dis)) 
 print('mean:Â ',Â np.mean(np_normal_dis)) 
 print('median:Â ',Â np.median(np_normal_dis)) 
 print('mode:Â ',Â stats.mode(np_normal_dis)) 
 print('sd:Â ',Â np.std(np_normal_dis)) 
  
 plt.hist(np_normal_dis,Â color="grey",Â bins=21) 
 plt.show() 
  
 tempÂ =Â np.array([1,Â 2,Â 3,Â 4,Â 5]) 
 pressureÂ =Â tempÂ *Â 2Â +Â 5 
  
 plt.plot(temp,Â pressure) 
 plt.xlabel('TemperatureÂ inÂ oC') 
 plt.ylabel('PressureÂ inÂ atm') 
 plt.title('TemperatureÂ vsÂ Pressure') 
 plt.xticks(np.arange(0,Â 6,Â step=0.5)) 
 plt.show() 
  
 muÂ =Â 28 
 sigmaÂ =Â 15 
 samplesÂ =Â 100000 
  
 xÂ =Â np.random.normal(mu,Â sigma,Â samples) 
 axÂ =Â sns.displot(x) 
 ax.set(xlabel="x",Â ylabel='y') 
 plt.show()
