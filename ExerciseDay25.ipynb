# %%
importÂ pandasÂ asÂ pd 
  
 dfÂ =Â pd.read_csv(r'data\hacker_news.csv') 
  
 first_5_rowsÂ =Â df.head() 
 #Â print(first_5_rows) 
  
 last_5_rowsÂ =Â df.tail() 
 #Â print(last_5_rows) 
  
 title_seriesÂ =Â df.iloc[:,2] 
 #Â print(title_series) 
  
 #Â print(df.shape) 
  
 python_titleÂ =Â df.loc[df['title'].str.contains('Python',Â case=False)] 
 #Â print(python_title) 
  
 js_titleÂ =Â df.loc[df['title'].str.contains('JavaScript',Â case=False)] 
 #Â print(js_title) 
  
 #Â print(df.describe())
